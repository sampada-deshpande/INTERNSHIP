# %% [markdown]
# DATE:30/12/2025
#
# ENCAPSULATION
# Encapsulation is an Object-Oriented Programming (OOP) concept that binds data (variables) and methods (functions) together into a single unit (class) and restricts direct access to some of the object’s data.
#
#  In simple words:
#
# Encapsulation = Data hiding + Controlled access
#
# Need of encapsulation:
#
# Protects data from unauthorized access
# Improves security
# Helps in data validation
# Makes code maintainable
